# %%
import numpy as np
import skimage
from skimage import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sample_image = np.random.random([300,300])

# %%
plt.imshow(sample_image)

# %%
plt.imshow(sample_image,cmap='gray',interpolation='nearest')
plt.xticks([])
plt.yticks([]);

# %%
plt.imshow(sample_image,cmap='Spectral',interpolation='nearest')
plt.xticks([])
plt.yticks([]);

# %%
camera = data.camera()
plt.figure(figsize=(8,6))
plt.imshow(camera,cmap='gray',interpolation='nearest')

# %%
camera.min()
# Out:
# 0

# %%
camera.shape
# Out:
# (512, 512)

# %%
camera.min(),camera.max(),camera.mean(),camera.std()
# Out:
# (0, 255, 118.31400299072266, 61.9960435760992)

# %%
tree = skimage.io.imread('images\pexels-tree.jpg',as_gray=True)
plt.imshow(tree,cmap='gray')

# %%
tree_copy = tree.copy()
tree_inverted = 1-tree_copy
plt.imshow(tree_inverted,cmap='gray')

# %%
mask=tree_copy<0.5
tree_copy[mask] = 1

# %%
plt.imshow(tree_copy,cmap='gray')

# %% [markdown]
# ### Lets pic som ecolor images

# %%
parrot_img=skimage.io.imread('images/pexels-parrot.jpg')
plt.imshow(parrot_img,interpolation='nearest')

# %%
parrot_img.shape
# Out:
# (2848, 4272, 3)

# %%
parrot_img
# Out:
# array([[[16, 22, 12],
#         [16, 22, 12],
#         [16, 22, 12],
#         ...,
#         [19, 20, 14],
#         [19, 20, 15],
#         [19, 20, 15]],
#
#        [[15, 23, 12],
#         [15, 23, 12],
#         [16, 22, 12],
#         ...,
#         [19, 20, 14],
#         [19, 20, 15],
#         [19, 20, 15]],
#
#        [[15, 23, 12],
#         [15, 23, 12],
#         [15, 23, 12],
#         ...,
#         [19, 20, 14],
#         [18, 19, 14],
#         [18, 19, 14]],
#
#        ...,
#
#        [[18, 32, 19],
#         [18, 32, 19],
#         [18, 32, 19],
#         ...,
#         [15, 18, 11],
#         [15, 18, 11],
#         [15, 18, 11]],
#
#        [[17, 31, 18],
#         [17, 31, 18],
#         [18, 30, 18],
#         ...,
#         [15, 18, 11],
#         [15, 18, 11],
#         [15, 18, 11]],
#
#        [[16, 29, 19],
#         [17, 31, 18],
#         [18, 30, 18],
#         ...,
#         [15, 18, 11],
#         [15, 18, 11],
#         [15, 18, 11]]], dtype=uint8)

# %%
parrot_more_green = parrot_img.copy()
green_mask = parrot_more_green[:,:,1]  < 15
red_mask = parrot_more_green[:,:,0]  < 15
blue_mask = parrot_more_green[:,:,2]  < 15

parrot_more_green[green_mask] = [0,255,0]
parrot_more_green[blue_mask] = [0,0,255]
parrot_more_green[red_mask] = [255,0,0]
plt.imshow(parrot_more_green)

# %%
parrot_zoom = parrot_img[875:1000,500:1000]
plt.imshow(parrot_zoom)

# %%
many_trees = np.array([tree.copy(),tree.copy(),tree.copy(),tree.copy()])

# %%
many_trees.shape
# Out:
# (4, 350, 526)
